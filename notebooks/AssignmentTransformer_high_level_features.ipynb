# %%
import sys

sys.path.append("..")
from core.DataLoader import (
    DataPreprocessor,
    DataConfig,
    LoadConfig,
    get_load_config_from_yaml,
)
import numpy as np
from importlib import reload
import matplotlib.pyplot as plt
import yaml
import core.assignment_models as Models
import core
import keras
import tensorflow as tf


PLOTS_DIR = f"plots/assignment_transformer_high_level_features/"
MODEL_DIR = f"models/assignment_transformer_high_level_features/"
import os

if not os.path.exists(PLOTS_DIR):
    os.makedirs(PLOTS_DIR)
if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)


load_config = get_load_config_from_yaml("workspace_config_high_level_features.yaml")

DataProcessor = DataPreprocessor(load_config)

data_config_path = "workspace_config_high_level_features.yaml"
with open(data_config_path, "r") as file:
    data_configs = yaml.safe_load(file)

data_config = DataProcessor.load_data(
    data_configs["data_path"]["nominal"], "reco", max_events=500000
)
X_train, y_train, X_val, y_val = DataProcessor.split_data(test_size=0.1)
del DataProcessor
# Out:
# 2025-11-12 22:12:06.301493: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762981926.326105 2451784 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762981926.334393 2451784 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762981926.354073 2451784 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762981926.354102 2451784 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762981926.354105 2451784 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762981926.354107 2451784 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-12 22:12:06.359637: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Removed 1562 events with negative weights

# %%
reload(Models)
reload(core)
TransformerMatcher = Models.FeatureConcatTransformer(data_config, name="Transformer")

#TransformerMatcher.load_model(MODEL_DIR + "model.keras")

TransformerMatcher.build_model(
    hidden_dim=64,
    num_layers = 6,
    num_heads = 8,
    dropout_rate=0.1,
)

TransformerMatcher.adapt_normalization_layers(X_train)

TransformerMatcher.compile_model(
    loss={
        "assignment": core.utils.AssignmentLoss(lambda_excl=0.0),
    },
    optimizer=keras.optimizers.AdamW(learning_rate=1e-4, weight_decay=1e-4),
    metrics={
        "assignment": [core.utils.AssignmentAccuracy()],
    },
)
TransformerMatcher.model.summary()
# Out:
# FeatureConcatTransformer is designed for classification tasks; regression targets will be ignored.
# I0000 00:00:1762981974.273078 2451784 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:65:00.0, compute capability: 6.0
# WARNING: Regression targets are specified in the config, but regression_output is None.
# Building model without regression output.
# Model: "FeatureConcatTransformerModel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ met_inputs          │ (None, 1, 2)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lep_inputs          │ (None, 2, 4)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ met_input_transform │ (None, 1, 2)      │          0 │ met_inputs[0][0]  │
# │ (InputMetPhiLayer)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lep_input_transform │ (None, 2, 4)      │          0 │ lep_inputs[0][0]  │
# │ (InputPtEtaPhiELay… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ jet_inputs          │ (None, 6, 9)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ met_input_normaliz… │ (None, 1, 2)      │          5 │ met_input_transf… │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lep_input_normaliz… │ (None, 2, 4)      │          9 │ lep_input_transf… │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ jet_input_transform │ (None, 6, 9)      │          0 │ jet_inputs[0][0]  │
# │ (InputPtEtaPhiELay… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 2)         │          0 │ met_input_normal… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 8)         │          0 │ lep_input_normal… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ jet_input_normaliz… │ (None, 6, 9)      │         19 │ jet_input_transf… │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector       │ (None, 6, 2)      │          0 │ flatten[0][0]     │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector_1     │ (None, 6, 8)      │          0 │ flatten_1[0][0]   │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 6, 19)     │          0 │ jet_input_normal… │
# │ (Concatenate)       │                   │            │ repeat_vector[0]… │
# │                     │                   │            │ repeat_vector_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ jet_embedding (MLP) │ (None, 6, 64)     │      4,530 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ jet_mask            │ (None, 6, 1)      │          0 │ jet_inputs[0][0]  │
# │ (GenerateMask)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ self_attention_blo… │ (None, 6, 64)     │     33,472 │ jet_embedding[0]… │
# │ (SelfAttentionBloc… │                   │            │ jet_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ self_attention_blo… │ (None, 6, 64)     │     33,472 │ self_attention_b… │
# │ (SelfAttentionBloc… │                   │            │ jet_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ self_attention_blo… │ (None, 6, 64)     │     33,472 │ self_attention_b… │
# │ (SelfAttentionBloc… │                   │            │ jet_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ self_attention_blo… │ (None, 6, 64)     │     33,472 │ self_attention_b… │
# │ (SelfAttentionBloc… │                   │            │ jet_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ self_attention_blo… │ (None, 6, 64)     │     33,472 │ self_attention_b… │
# │ (SelfAttentionBloc… │                   │            │ jet_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ self_attention_blo… │ (None, 6, 64)     │     33,472 │ self_attention_b… │
# │ (SelfAttentionBloc… │                   │            │ jet_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ jet_output_embeddi… │ (None, 6, 2)      │      1,440 │ self_attention_b… │
# │ (MLP)               │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ assignment          │ (None, 6, 2)      │          0 │ jet_output_embed… │
# │ (TemporalSoftmax)   │                   │            │ jet_mask[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 206,835 (807.96 KB)
#  Trainable params: 206,802 (807.82 KB)
#  Non-trainable params: 33 (144.00 B)

# %%
TransformerMatcher.train_model(
    epochs=100,
    X_train=X_train,
    y_train=y_train,
    sample_weights=core.utils.compute_sample_weights(X_train, y_train),
    batch_size=1024 * 2,
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762981992.618026 2452717 service.cc:152] XLA service 0x7f7ec800f3a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1762981992.618054 2452717 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2025-11-12 22:13:13.226081: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-12 22:13:13.963212: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator FeatureConcatTransformerModel_1/met_input_transform_1/assert_equal_1/Assert/Assert
# I0000 00:00:1762981995.831553 2452717 cuda_dnn.cc:529] Loaded cuDNN version 91500
# 2025-11-12 22:13:30.877228: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion_2', 56 bytes spill stores, 56 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion', 56 bytes spill stores, 56 bytes spill loads
#   6/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.1154 - loss: 7.6308e-04
# I0000 00:00:1762982011.202539 2452717 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 173/176 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - assignment_accuracy: 0.1183 - loss: 6.4086e-04
# 2025-11-12 22:13:36.396689: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator FeatureConcatTransformerModel_1/met_input_transform_1/assert_equal_1/Assert/Assert
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - assignment_accuracy: 0.1190 - loss: 6.4001e-04
# 2025-11-12 22:13:52.816173: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator FeatureConcatTransformerModel_1/met_input_transform_1/assert_equal_1/Assert/Assert
# 2025-11-12 22:13:54.495825: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator FeatureConcatTransformerModel_1/met_input_transform_1/assert_equal_1/Assert/Assert
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 58s 141ms/step - assignment_accuracy: 0.1192 - loss: 6.3975e-04 - val_assignment_accuracy: 0.3760 - val_loss: 4.2412e-04
# Epoch 2/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.3530 - loss: 4.6960e-04 - val_assignment_accuracy: 0.4657 - val_loss: 3.5716e-04
# Epoch 3/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.4204 - loss: 4.1289e-04 - val_assignment_accuracy: 0.4809 - val_loss: 3.3301e-04
# Epoch 4/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.4555 - loss: 3.7849e-04 - val_assignment_accuracy: 0.4700 - val_loss: 3.2433e-04
# Epoch 5/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.4646 - loss: 3.6673e-04 - val_assignment_accuracy: 0.5042 - val_loss: 3.1056e-04
# Epoch 6/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.4885 - loss: 3.5179e-04 - val_assignment_accuracy: 0.5347 - val_loss: 3.0001e-04
# Epoch 7/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.5041 - loss: 3.4326e-04 - val_assignment_accuracy: 0.5146 - val_loss: 2.9687e-04
# Epoch 8/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.5135 - loss: 3.3328e-04 - val_assignment_accuracy: 0.5423 - val_loss: 2.8805e-04
# Epoch 9/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.5276 - loss: 3.2163e-04 - val_assignment_accuracy: 0.5558 - val_loss: 2.8599e-04
# Epoch 10/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.5397 - loss: 3.1931e-04 - val_assignment_accuracy: 0.5676 - val_loss: 2.8038e-04
# Epoch 11/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.5472 - loss: 3.1208e-04 - val_assignment_accuracy: 0.5595 - val_loss: 2.7783e-04
# Epoch 12/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.5506 - loss: 3.0833e-04 - val_assignment_accuracy: 0.5817 - val_loss: 2.7278e-04
# Epoch 13/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.5638 - loss: 3.0187e-04 - val_assignment_accuracy: 0.5796 - val_loss: 2.7083e-04
# Epoch 14/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.5650 - loss: 2.9793e-04 - val_assignment_accuracy: 0.5952 - val_loss: 2.6728e-04
# Epoch 15/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.5698 - loss: 2.9435e-04 - val_assignment_accuracy: 0.5765 - val_loss: 2.6645e-04
# Epoch 16/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.5793 - loss: 2.8948e-04 - val_assignment_accuracy: 0.6007 - val_loss: 2.6228e-04
# Epoch 17/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.5862 - loss: 2.8497e-04 - val_assignment_accuracy: 0.6077 - val_loss: 2.5918e-04
# Epoch 18/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.5960 - loss: 2.8363e-04 - val_assignment_accuracy: 0.6097 - val_loss: 2.5655e-04
# Epoch 19/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.5964 - loss: 2.8099e-04 - val_assignment_accuracy: 0.6149 - val_loss: 2.5465e-04
# Epoch 20/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6083 - loss: 2.7766e-04 - val_assignment_accuracy: 0.6016 - val_loss: 2.5088e-04
# Epoch 21/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6025 - loss: 2.7366e-04 - val_assignment_accuracy: 0.6271 - val_loss: 2.4625e-04
# Epoch 22/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6174 - loss: 2.6867e-04 - val_assignment_accuracy: 0.6235 - val_loss: 2.4459e-04
# Epoch 23/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6178 - loss: 2.6743e-04 - val_assignment_accuracy: 0.6211 - val_loss: 2.4227e-04
# Epoch 24/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6171 - loss: 2.6423e-04 - val_assignment_accuracy: 0.6465 - val_loss: 2.3887e-04
# Epoch 25/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6319 - loss: 2.6344e-04 - val_assignment_accuracy: 0.6346 - val_loss: 2.3809e-04
# Epoch 26/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6416 - loss: 2.5873e-04 - val_assignment_accuracy: 0.6324 - val_loss: 2.3638e-04
# Epoch 27/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6430 - loss: 2.5651e-04 - val_assignment_accuracy: 0.6597 - val_loss: 2.3277e-04
# Epoch 28/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6516 - loss: 2.5249e-04 - val_assignment_accuracy: 0.6524 - val_loss: 2.3169e-04
# Epoch 29/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6442 - loss: 2.5250e-04 - val_assignment_accuracy: 0.6655 - val_loss: 2.2976e-04
# Epoch 30/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6539 - loss: 2.4909e-04 - val_assignment_accuracy: 0.6640 - val_loss: 2.2850e-04
# Epoch 31/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6573 - loss: 2.4602e-04 - val_assignment_accuracy: 0.6740 - val_loss: 2.2721e-04
# Epoch 32/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6568 - loss: 2.4809e-04 - val_assignment_accuracy: 0.6819 - val_loss: 2.2570e-04
# Epoch 33/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6632 - loss: 2.4554e-04 - val_assignment_accuracy: 0.6686 - val_loss: 2.2641e-04
# Epoch 34/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6692 - loss: 2.4067e-04 - val_assignment_accuracy: 0.6940 - val_loss: 2.2357e-04
# Epoch 35/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6626 - loss: 2.4384e-04 - val_assignment_accuracy: 0.7043 - val_loss: 2.2376e-04
# Epoch 36/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6821 - loss: 2.3961e-04 - val_assignment_accuracy: 0.7048 - val_loss: 2.2203e-04
# Epoch 37/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6792 - loss: 2.4112e-04 - val_assignment_accuracy: 0.6852 - val_loss: 2.2159e-04
# Epoch 38/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6804 - loss: 2.3919e-04 - val_assignment_accuracy: 0.6873 - val_loss: 2.2187e-04
# Epoch 39/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6799 - loss: 2.3706e-04 - val_assignment_accuracy: 0.6875 - val_loss: 2.2131e-04
# Epoch 40/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6847 - loss: 2.3525e-04 - val_assignment_accuracy: 0.6849 - val_loss: 2.2108e-04
# Epoch 41/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6721 - loss: 2.3702e-04 - val_assignment_accuracy: 0.6876 - val_loss: 2.2082e-04
# Epoch 42/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6830 - loss: 2.3556e-04 - val_assignment_accuracy: 0.7082 - val_loss: 2.1881e-04
# Epoch 43/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6929 - loss: 2.3288e-04 - val_assignment_accuracy: 0.6871 - val_loss: 2.1953e-04
# Epoch 44/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6903 - loss: 2.3470e-04 - val_assignment_accuracy: 0.7052 - val_loss: 2.1830e-04
# Epoch 45/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6905 - loss: 2.3085e-04 - val_assignment_accuracy: 0.6961 - val_loss: 2.1765e-04
# Epoch 46/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6982 - loss: 2.3189e-04 - val_assignment_accuracy: 0.7177 - val_loss: 2.1717e-04
# Epoch 47/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6919 - loss: 2.3283e-04 - val_assignment_accuracy: 0.6991 - val_loss: 2.1744e-04
# Epoch 48/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6980 - loss: 2.3263e-04 - val_assignment_accuracy: 0.7205 - val_loss: 2.1651e-04
# Epoch 49/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.6981 - loss: 2.3133e-04 - val_assignment_accuracy: 0.7338 - val_loss: 2.1566e-04
# Epoch 50/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7164 - loss: 2.2785e-04 - val_assignment_accuracy: 0.7349 - val_loss: 2.1562e-04
# Epoch 51/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7151 - loss: 2.2981e-04 - val_assignment_accuracy: 0.7357 - val_loss: 2.1549e-04
# Epoch 52/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7140 - loss: 2.2904e-04 - val_assignment_accuracy: 0.7389 - val_loss: 2.1533e-04
# Epoch 53/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7166 - loss: 2.2820e-04 - val_assignment_accuracy: 0.7151 - val_loss: 2.1620e-04
# Epoch 54/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7070 - loss: 2.2718e-04 - val_assignment_accuracy: 0.7317 - val_loss: 2.1467e-04
# Epoch 55/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7123 - loss: 2.2832e-04 - val_assignment_accuracy: 0.7335 - val_loss: 2.1392e-04
# Epoch 56/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7177 - loss: 2.2566e-04 - val_assignment_accuracy: 0.7211 - val_loss: 2.1468e-04
# Epoch 57/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7060 - loss: 2.2790e-04 - val_assignment_accuracy: 0.7367 - val_loss: 2.1320e-04
# Epoch 58/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7195 - loss: 2.2420e-04 - val_assignment_accuracy: 0.7418 - val_loss: 2.1342e-04
# Epoch 59/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7180 - loss: 2.2565e-04 - val_assignment_accuracy: 0.7448 - val_loss: 2.1236e-04
# Epoch 60/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7229 - loss: 2.2368e-04 - val_assignment_accuracy: 0.7280 - val_loss: 2.1319e-04
# Epoch 61/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7090 - loss: 2.2763e-04 - val_assignment_accuracy: 0.7378 - val_loss: 2.1227e-04
# Epoch 62/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7225 - loss: 2.2528e-04 - val_assignment_accuracy: 0.7374 - val_loss: 2.1185e-04
# Epoch 63/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7190 - loss: 2.2270e-04 - val_assignment_accuracy: 0.7435 - val_loss: 2.1196e-04
# Epoch 64/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7195 - loss: 2.2349e-04 - val_assignment_accuracy: 0.7432 - val_loss: 2.1157e-04
# Epoch 65/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7190 - loss: 2.2376e-04 - val_assignment_accuracy: 0.7437 - val_loss: 2.1128e-04
# Epoch 66/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7248 - loss: 2.2161e-04 - val_assignment_accuracy: 0.7429 - val_loss: 2.1177e-04
# Epoch 67/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7255 - loss: 2.2317e-04 - val_assignment_accuracy: 0.7516 - val_loss: 2.1086e-04
# Epoch 68/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7260 - loss: 2.2142e-04 - val_assignment_accuracy: 0.7526 - val_loss: 2.1132e-04
# Epoch 69/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7234 - loss: 2.2399e-04 - val_assignment_accuracy: 0.7599 - val_loss: 2.1088e-04
# Epoch 70/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7375 - loss: 2.2196e-04 - val_assignment_accuracy: 0.7572 - val_loss: 2.1065e-04
# Epoch 71/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7343 - loss: 2.2060e-04 - val_assignment_accuracy: 0.7615 - val_loss: 2.1040e-04
# Epoch 72/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7373 - loss: 2.2362e-04 - val_assignment_accuracy: 0.7618 - val_loss: 2.1005e-04
# Epoch 73/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7397 - loss: 2.2164e-04 - val_assignment_accuracy: 0.7651 - val_loss: 2.0929e-04
# Epoch 74/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7269 - loss: 2.2214e-04 - val_assignment_accuracy: 0.7628 - val_loss: 2.0957e-04
# Epoch 75/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7351 - loss: 2.1984e-04 - val_assignment_accuracy: 0.7610 - val_loss: 2.1035e-04
# Epoch 76/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7362 - loss: 2.2143e-04 - val_assignment_accuracy: 0.7622 - val_loss: 2.0951e-04
# Epoch 77/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7341 - loss: 2.2246e-04 - val_assignment_accuracy: 0.7577 - val_loss: 2.0918e-04
# Epoch 78/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7305 - loss: 2.1740e-04 - val_assignment_accuracy: 0.7628 - val_loss: 2.0876e-04
# Epoch 79/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7398 - loss: 2.1512e-04 - val_assignment_accuracy: 0.7613 - val_loss: 2.0905e-04
# Epoch 80/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7382 - loss: 2.2204e-04 - val_assignment_accuracy: 0.7641 - val_loss: 2.0985e-04
# Epoch 81/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7410 - loss: 2.1964e-04 - val_assignment_accuracy: 0.7656 - val_loss: 2.0938e-04
# Epoch 82/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7384 - loss: 2.2124e-04 - val_assignment_accuracy: 0.7615 - val_loss: 2.0898e-04
# Epoch 83/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7383 - loss: 2.1781e-04 - val_assignment_accuracy: 0.7657 - val_loss: 2.0837e-04
# Epoch 84/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7382 - loss: 2.1778e-04 - val_assignment_accuracy: 0.7625 - val_loss: 2.0870e-04
# Epoch 85/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7397 - loss: 2.1847e-04 - val_assignment_accuracy: 0.7665 - val_loss: 2.0825e-04
# Epoch 86/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7426 - loss: 2.1776e-04 - val_assignment_accuracy: 0.7679 - val_loss: 2.0775e-04
# Epoch 87/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7433 - loss: 2.1708e-04 - val_assignment_accuracy: 0.7638 - val_loss: 2.0833e-04
# Epoch 88/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7399 - loss: 2.1966e-04 - val_assignment_accuracy: 0.7686 - val_loss: 2.0780e-04
# Epoch 89/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7447 - loss: 2.1761e-04 - val_assignment_accuracy: 0.7703 - val_loss: 2.0814e-04
# Epoch 90/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7468 - loss: 2.1474e-04 - val_assignment_accuracy: 0.7708 - val_loss: 2.0763e-04
# Epoch 91/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7462 - loss: 2.1616e-04 - val_assignment_accuracy: 0.7682 - val_loss: 2.0802e-04
# Epoch 92/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7453 - loss: 2.1731e-04 - val_assignment_accuracy: 0.7681 - val_loss: 2.0745e-04
# Epoch 93/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7439 - loss: 2.1712e-04 - val_assignment_accuracy: 0.7676 - val_loss: 2.0771e-04
# Epoch 94/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7448 - loss: 2.1719e-04 - val_assignment_accuracy: 0.7693 - val_loss: 2.0715e-04
# Epoch 95/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7465 - loss: 2.1583e-04 - val_assignment_accuracy: 0.7708 - val_loss: 2.0732e-04
# Epoch 96/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7455 - loss: 2.1598e-04 - val_assignment_accuracy: 0.7687 - val_loss: 2.0698e-04
# Epoch 97/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7462 - loss: 2.1592e-04 - val_assignment_accuracy: 0.7697 - val_loss: 2.0718e-04
# Epoch 98/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7474 - loss: 2.1604e-04 - val_assignment_accuracy: 0.7713 - val_loss: 2.0698e-04
# Epoch 99/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7468 - loss: 2.1656e-04 - val_assignment_accuracy: 0.7686 - val_loss: 2.0661e-04
# Epoch 100/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - assignment_accuracy: 0.7453 - loss: 2.1673e-04 - val_assignment_accuracy: 0.7687 - val_loss: 2.0745e-04

# %%
TransformerMatcher.save_model(MODEL_DIR + "model.keras")
# Out:
# Model saved to models/assignment_transformer_high_level_features/model.keras

# %%
import core.assignment_models.BaselineAssignmentMethods as BaselineMethods
import core.reconstruction as Evaluation

reload(Evaluation)
reload(BaselineMethods)
delta_r_assigner = BaselineMethods.DeltaRAssigner(
    data_config,
    use_nu_flows=True,
)
chi_square_true_nu = BaselineMethods.MassCombinatoricsAssigner(
    data_config,
    use_nu_flows=False,
    use_nu_flows_for_assignment=True,
    top_mass=173.5e3,
)
chi_square = BaselineMethods.MassCombinatoricsAssigner(
    data_config,
    use_nu_flows=True,
    use_nu_flows_for_assignment=True,
    top_mass=173.5e3,
)


ground_truth_assigner = Evaluation.GroundTruthReconstructor(
    data_config, name="True Assignment"
)
evaluator = Evaluation.ReconstructionEvaluator(
    [
        ground_truth_assigner,
        # delta_r_assigner,
        chi_square_true_nu,
        chi_square,
        TransformerMatcher,
    ],
    X_val,
    y_val,
)
# Out:
# WARNING: 'nu_flows_regression_targets' not found in data_dict. Returning 'regression_targets' instead.
# 2025-11-12 22:21:13.761900: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator FeatureConcatTransformerModel_1/met_input_transform_1/assert_equal_1/Assert/Assert
# 2025-11-12 22:21:16.865227: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator FeatureConcatTransformerModel_1/met_input_transform_1/assert_equal_1/Assert/Assert

# %%
fig, ax = evaluator.plot_all_accuracies()
fig.savefig(PLOTS_DIR + "all_accuracies.pdf")
# Out:
# Computing bootstrap confidence intervals...
# True Assignment: Ground Truth (skipping)
# $\chi^2$-Method(True $\nu$): 0.6171 [0.6126, 0.6211]
# $\chi^2$-Method($\nu^2$-Flows): 0.6171 [0.6129, 0.6211]
# Transformer: 0.7918 [0.7885, 0.7953]

# %%
fig, ax = evaluator.plot_binned_top_mass_resolution(
    feature_data_type="non_training",
    feature_name="truth_ttbar_mass",
    fancy_feature_label=r"$m(t\overline{t})$ [GeV]",
    xlims=(340e3, 800e3),
)
ticks = ax.get_xticks()
ax.set_xticks(ticks)
ax.set_xticklabels([f"{int(tick/1e3)}" for tick in ticks])
ax.set_xlim(340e3, 800e3)
fig.savefig(PLOTS_DIR + "top_mass_resolution_comparison.pdf")
# Out:
# Computing binned top mass resolution for truth_ttbar_mass...

# %%
fig, ax = evaluator.plot_binned_ttbar_mass_resolution(
    feature_data_type="non_training",
    feature_name="truth_ttbar_mass",
    fancy_feature_label=r"$m(t\overline{t})$ [GeV]",
    xlims=(340e3, 800e3),
)
ticks = ax.get_xticks()
ax.set_xticks(ticks)
ax.set_xticklabels([f"{int(tick/1e3)}" for tick in ticks])
ax.set_xlim(340e3, 800e3)
ax.set_ylim(0, 0.3)
fig.savefig(PLOTS_DIR + "ttbar_mass_resolution_comparison.pdf")
# Out:
# Computing binned ttbar mass resolution for truth_ttbar_mass...

# %%
fig, ax = evaluator.plot_binned_complementarity(
    feature_data_type="non_training",
    feature_name="truth_ttbar_mass",
    fancy_feature_label=r"$m(t\overline{t})$ [GeV]",
    xlims=(340e3, 800e3),
)
ticks = ax.get_xticks()
ax.set_xticks(ticks)
ax.set_xticklabels([f"{int(tick/1e3)}" for tick in ticks])
ax.set_xlim(340e3, 800e3)

fig.savefig(PLOTS_DIR + "binned_complementarity_ttbar_mass.pdf")
# Out:
# Computing binned complementarity for truth_ttbar_mass...

# %%
fig, ax = evaluator.plot_binned_accuracy(
    feature_data_type="non_training",
    feature_name="truth_ttbar_mass",
    fancy_feature_label=r"$m(t\overline{t})$ [GeV]",
    xlims=(340e3, 800e3),
    bins=10,
)
ticks = ax.get_xticks()
ax.set_xticks(ticks)
ax.set_xticklabels([f"{int(tick/1e3)}" for tick in ticks])
ax.set_xlim(340e3, 800e3)
fig.savefig(PLOTS_DIR + "binned_accuracy_ttbar_mass.pdf")
# Out:
# Computing binned accuracy for truth_ttbar_mass...

# %%
fig, ax = evaluator.plot_binned_accuracy(
    feature_data_type="non_training",
    feature_name="truth_ttbar_pt",
    fancy_feature_label=r"$p_T(t\overline{t})$ [GeV]",
    xlims=(0, 400e3),
    bins=10,
)
ticks = ax.get_xticks()
ax.set_xticks(ticks)
ax.set_xticklabels([f"{int(tick/1e3)}" for tick in ticks])
ax.set_xlim(0, 400e3)

fig.savefig(PLOTS_DIR + "binned_accuracy_ttbar_pT.pdf")
# Out:
# Computing binned accuracy for truth_ttbar_pt...

# %%
fig, ax = evaluator.plot_binned_accuracy(
    feature_data_type="non_training",
    feature_name="truth_initial_parton_num_gluons",
    fancy_feature_label=r"Initial State",
    xlims=(0, 3),
    bins=3,
)
ax.set_xticks([0.5, 1.5, 2.5])
ax.set_xticklabels([r"$qq\to tt$", r"$qg\to tt$", r"$gg\to tt$"])
fig.savefig(PLOTS_DIR + "binned_accuracy_initial_state.pdf")
# Out:
# Computing binned accuracy for truth_initial_parton_num_gluons...

# %%
fig, ax = evaluator.plot_binned_accuracy(
    feature_data_type="non_training",
    feature_name="N_jets",
    fancy_feature_label=r"$\# \text{jets}$",
    xlims=(2, data_configs["LoadConfig"]["max_jets"] + 1),
    bins=data_configs["LoadConfig"]["max_jets"] - 1,
)
ax.set_xticks([i + 0.5 for i in range(2, data_configs["LoadConfig"]["max_jets"] + 1)])
ax.set_xticklabels([i for i in range(2, data_configs["LoadConfig"]["max_jets"] + 1)])
fig.savefig(PLOTS_DIR + "binned_accuracy_N_jets.pdf")
# Out:
# Computing binned accuracy for N_jets...

# %%
fig, ax = evaluator.plot_confusion_matrices()
fig.savefig(PLOTS_DIR + "confusion_matrices.pdf")

# %%
fig, ax = evaluator.plot_complementarity_matrix(figsize=(8.5, 8))
fig.savefig(PLOTS_DIR + "complementarity_matrix.pdf")
